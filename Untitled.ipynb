# %% [markdown]
# # Projeto Análise de dados de pessoas com Diabetes

# %% [markdown]
# ### Objetivo deste projeto é visualizar os dados presentes e identificar quaisquer que sejam as anomalias se há dados missing, se existe alguma correlação entre varáveis, fazer o pré-processamento dos dados e ao final do projeto responder algumas perguntas de negócios.

# %% [markdown]
# ##### Os dados usados: https://www.kaggle.com/code/priyamchoksi/diabetes-prediction-model

# %% [markdown]
# #### Este projeto será divido em 3 etapas
# 1°- Exploração e visualização dos dados
#
# 2°- Pré-processamento dos dados para modelos de machine learning
#
# 3°- Respoder perguntas de negócios

# %%
##IMPORTANDO AS BIBLIOTECAS NECESSÁRIAS
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
df = pd.read_csv('diabetes_dataset.csv')

# %% [markdown]
# ###### ----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# ### Análise Exploratória

# %% [markdown]
# ### O conjunto de dados contém informações sobre pacientes, incluindo características demográficas, históricos médicos e medições de saúde. As colunas incluem:
# ##### year: Ano da coleta de dados.
# ##### gender: Gênero do paciente.
# ##### age: Idade do paciente.
# ##### location: Localização.
# ##### race: Indicações de raça.
# ##### hypertension: Se o paciente tem hipertensão.
# ##### heart_disease: Se o paciente tem doença cardíaca.
# ##### smoking_history: Histórico de tabagismo.
# ##### bmi: Índice de Massa Corporal.
# ##### hbA1c_level: Nível de HbA1c.
# ##### blood_glucose_level: Nível de glicose no sangue.
# ##### diabetes: Indicador de diabetes.

# %% [markdown]
# ##### Estatística Descritiva
#   #### Variáveis Numéricas

# %%
df.describe()
# Out:
#                 year            age  race:AfricanAmerican     race:Asian  \
# count  100000.000000  100000.000000         100000.000000  100000.000000
# mean     2018.360820      41.885856              0.202230       0.200150
# std         1.345239      22.516840              0.401665       0.400114
# min      2015.000000       0.080000              0.000000       0.000000
# 25%      2019.000000      24.000000              0.000000       0.000000
# 50%      2019.000000      43.000000              0.000000       0.000000
# 75%      2019.000000      60.000000              0.000000       0.000000
# max      2022.000000      80.000000              1.000000       1.000000
#
#        race:Caucasian  race:Hispanic     race:Other  hypertension  \
# count   100000.000000   100000.00000  100000.000000  100000.00000
# mean         0.198760        0.19888       0.199980       0.07485
# std          0.399069        0.39916       0.399987       0.26315
# min          0.000000        0.00000       0.000000       0.00000
# 25%          0.000000        0.00000       0.000000       0.00000
# 50%          0.000000        0.00000       0.000000       0.00000
# 75%          0.000000        0.00000       0.000000       0.00000
# max          1.000000        1.00000       1.000000       1.00000
#
#        heart_disease            bmi    hbA1c_level  blood_glucose_level  \
# count  100000.000000  100000.000000  100000.000000        100000.000000
# mean        0.039420      27.320767       5.527507           138.058060
# std         0.194593       6.636783       1.070672            40.708136
# min         0.000000      10.010000       3.500000            80.000000
# 25%         0.000000      23.630000       4.800000           100.000000
# 50%         0.000000      27.320000       5.800000           140.000000
# 75%         0.000000      29.580000       6.200000           159.000000
# max         1.000000      95.690000       9.000000           300.000000
#
#             diabetes
# count  100000.000000
# mean        0.085000
# std         0.278883
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         0.000000
# max         1.000000

# %% [markdown]
# #### Variáveis Categóricas

# %%
df.describe(include = object)
# Out:
#         gender location smoking_history
# count   100000   100000          100000
# unique       3       55               6
# top     Female     Iowa         No Info
# freq     58552     2038           35816

# %% [markdown]
# ### Resumo variáveis númericas :
# #### Esssa coleta começou no ano de 2015, o valor mediano dos dados coletados é de 2019 o final da coleta foi em 2022
# #### (temos um valor mínimo de 0.080000 na idade) temos que tratar esse valor, idade media é de 41 anos e a idade máxima 80 anos
# #### outro fato curioso é que existe um ser com 95.690000 bmi (Índice de massa corporal) foge total do padrão dos dados.
# ### Resumo varáveis categóricas:
# #### Três categorias (Female, Male e outra(s)).
# #### location: 55 localizações diferentes, com Iowa sendo a mais frequente.
# #### smoking_history: Seis categorias, com "No Info" sendo a mais frequente.

# %%
# Configurações de estilo
sns.set(style="whitegrid")

# Distribuição da Idade
plt.figure(figsize=(12, 6))
sns.histplot(df['age'], bins=30, kde=True, color='skyblue')
plt.title('Distribuição das Idades')
plt.xlabel('Idade')
plt.ylabel('Frequência')
plt.show()

# %% [markdown]
# #### Distribuição das Idades: Mostra que a maioria dos pacientes está concentrada entre 20 e 60 anos
# #### com uma pequena quantidade de pacientes mais jovens e mais velhos.

# %%
# Distribuição do IMC
plt.figure(figsize=(12, 6))
sns.histplot(df['bmi'], bins=30, kde=True, color='lightgreen')
plt.title('Distribuição do IMC')
plt.xlabel('IMC')
plt.ylabel('Frequência')
plt.show()

# %% [markdown]
# #### Distribuição do IMC: A maioria dos pacientes tem IMC entre 20 e 40, com alguns valores mais extremos.

# %%
# Distribuição do Nível de Glicose no Sangue
plt.figure(figsize=(12, 6))
sns.histplot(df['blood_glucose_level'], bins=30, kde=True, color='salmon')
plt.title('Distribuição do Nível de Glicose no Sangue')
plt.xlabel('Nível de Glicose no Sangue')
plt.ylabel('Frequência')
plt.show()

# %% [markdown]
# #### Distribuição do Nível de Glicose no Sangue: A maioria dos pacientes tem níveis de glicose no sangue entre 80 e 200, com picos ao redor de 100 e 160.

# %%
# Calcular a proporção de pacientes com diabetes
diabetes_counts = df['diabetes'].value_counts()
diabetes_proportion = diabetes_counts / len(df)

# Plotar a proporção de pacientes com diabetes
plt.figure(figsize=(8, 6))
sns.barplot(x=diabetes_proportion.index, y=diabetes_proportion.values, palette='muted')
plt.title('Proporção de Pacientes com Diabetes')
plt.xlabel('Diabetes')
plt.ylabel('Proporção')
plt.xticks([0, 1], ['Não', 'Sim'])
plt.show()

# %% [markdown]
# #### Proporção de Pacientes com Diabetes: Aproximadamente 8,5% dos pacientes têm diabetes.

# %%
# Distribuição por Gênero
plt.figure(figsize=(8, 6))
sns.countplot(df, x='gender', palette='pastel')
plt.title('Distribuição por Gênero')
plt.xlabel('Gênero')
plt.ylabel('Frequência')
plt.show()

# %% [markdown]
# #### Distribuição por Gênero: Mostra que há mais pacientes do gênero feminino do que masculino.

# %%
#Selecionar apenas colunas numéricas
numeric_cols = df.select_dtypes(include=[float, int]).columns

# Calcular Z-score apenas para colunas numéricas
z_scores = stats.zscore(df[numeric_cols])

# Criar um DataFrame com os Z-scores
z_scores_df = pd.DataFrame(z_scores, columns=numeric_cols)

# Filtrar linhas onde todos os Z-scores são menores que 3
df_cleaned = df[(z_scores_df < 3).all(axis=1)]

# Mostrar as primeiras linhas do DataFrame limpo
df_cleaned.head(50)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[19], line 5
#       2 numeric_cols = df.select_dtypes(include=[float, int]).columns
#       4 # Calcular Z-score apenas para colunas numéricas
# ----> 5 z_scores = stats.zscore(df[numeric_cols])
#       7 # Criar um DataFrame com os Z-scores
#       8 z_scores_df = pd.DataFrame(z_scores, columns=numeric_cols)
#
# NameError: name 'stats' is not defined
